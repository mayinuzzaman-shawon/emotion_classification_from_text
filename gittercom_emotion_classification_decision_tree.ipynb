# %%
# !pip install nlpaug
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nlpaug in /usr/local/lib/python3.10/dist-packages (1.1.11)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.10/dist-packages (from nlpaug) (1.22.4)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from nlpaug) (1.5.3)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.10/dist-packages (from nlpaug) (2.27.1)
# Requirement already satisfied: gdown>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from nlpaug) (4.6.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown>=4.0.0->nlpaug) (3.12.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown>=4.0.0->nlpaug) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown>=4.0.0->nlpaug) (4.65.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown>=4.0.0->nlpaug) (4.11.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.0->nlpaug) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.0->nlpaug) (2022.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->nlpaug) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->nlpaug) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->nlpaug) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->nlpaug) (3.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown>=4.0.0->nlpaug) (2.4.1)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->nlpaug) (1.7.1)

# %% [markdown]
# **Importing Necessary Libraries**

# %%
import pandas as pd
import re
import nlpaug.augmenter.word as naw
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, classification_report

# %% [markdown]
# **Loading the Dataset**

# %%
#reading the dataset in csv format

data = pd.read_csv('/content/drive/MyDrive/Datasets/gittercom_annotated_data.csv')

# %% [markdown]
# **Text Preprocessing**

# %%
def text_preprocessing(text):
    #removing punctuation from text data
    text = re.sub(r'[^\w\s]', '', text)

    #removing special symbols from text data
    text = re.sub(r'[^A-Za-z0-9\s]', '', text)

    #replacing usernames in text data with '<username>'
    text = re.sub(r'@[^\s]+', '<username>', text)

    #replacing url in text data with '<url>' 
    text = re.sub(r'http\S+|www\S+|\S+\.com\S+', '<url>', text)
    
    #replacing code snippets in text data with '<code>' 
    text = re.sub(r'`[^`]+`', '<code>', text)
    
    return text

# %% [markdown]
# **Applying Text Preprocessing to the Text Data**

# %%
#applying preprocessing techniques to the text data ('message' column holds all textual communications,i.e., text data)

data['message'] = data['message'].apply(text_preprocessing)

# %% [markdown]
# **Counting the Total Number of Instances of Our Dataset**

# %%
data.shape[0]
# Out:
# 1000

# %%
#exploring first five rows of our dataset

data.head()
# Out:
#     Channel                                            message  category
# 0  Cucumber  Hi Team I just recently upgraded our cucumberj...      fear
# 1  Cucumber               So github is trying to replace irc P      fear
# 2  Cucumber  aslakhellesoy Thanks  seems like I was using o...       joy
# 3  Cucumber        Sidkiyassine just call the methods directly  surprise
# 4  Cucumber  Hello guys need a helpI want to call the run m...      fear

# %%
#exploring the instances of message column that holds text data

data['message']
# Out:
# 0      Hi Team I just recently upgraded our cucumberj...
# 1                   So github is trying to replace irc P
# 2      aslakhellesoy Thanks  seems like I was using o...
# 3            Sidkiyassine just call the methods directly
# 4      Hello guys need a helpI want to call the run m...
#                              ...
# 995    Besides the unzip issue which I saw you solved...
# 996    Hopefully now that the unzip issue is fixed we...
# 997     I can see that being a problem with my community
# 998                       which would slow down installs
# 999         Thanks yet again Ill try your suggestion now
# Name: message, Length: 1000, dtype: object

# %% [markdown]
# **Splitting the Dataset for Classification**

# %%
X = data['message']
y = data['category']

#splitting the data into training and testing sets (70% for training and 30% for testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# **Data Augmentation of training data using Synonym**

# %%
augmented_data = []
augmented_category = []
no_of_targeted_augmentation = 30000

#initializing SynonymAug class of nlp aug library that leverage semantic meaning to substitute word using synonym
data_augmentation = naw.SynonymAug(aug_src='wordnet')

while len(augmented_data) < no_of_targeted_augmentation:
    for message, category in zip(X_train, y_train):
        augmented_text = data_augmentation.augment(message)
        augmented_data.append(augmented_text)
        augmented_category.append(category)
        if len(augmented_data) == no_of_targeted_augmentation:
            break

# %%
X_train = X_train.tolist() + augmented_data[:no_of_targeted_augmentation]
y_train = y_train.tolist() + augmented_category[:no_of_targeted_augmentation]

# %% [markdown]
# **Counting the Total Number of Instances of training data After Data Augmentation**

# %%
len(X_train)
# Out:
# 30700

# %% [markdown]
# **Dropping Any Possible Duplicate Instance(s) of Text Data Due to Performing Data Augmentation**

# %%
data.drop_duplicates(subset='message', inplace=True)

# %%
len(X_train)
# Out:
# 30700

# %% [markdown]
# **Exploring Augmented Text Data**

# %%
for message, category in zip(X_train, y_train):
    print("message:", message)
    print("category:", category)
# Out:
# Streaming output truncated to the last 5000 lines.
# message: ['as well jdubois cannot discover the gratuity folder <url >']
# category: sadness
# message: ['hawaii i am go into cucumberspring124 vs springboot130 progeny <url> javalangArrayStoreException sunreflectannotationTypeNotPresentExceptionProxy']
# category: fear
# message: ['1 wish i could do this kind of workplace for free as well but unfortunately its not potential correctly now but it would cost a dream come rightful to work full meter on a project like this']
# category: sadness
# message: ['So I would just extend that a litle chip possibly with a few notes to that effect and everything would be all ripe']
# category: joy
# message: ['Tips and tricks depend awing']
# category: joy
# message: ['Ping ping ping Iu2019d alike to receive the jspm workflow for infamous publish tonight D Just 380 needs a location or is it my fracture']
# category: joy
# message: ['National intelligence community an finish this with this']
# category: joy
# message: ['good affair theres a 2vs2 and could play along with him vs others']
# category: joy
# message: ['trusktr I in conclusion agree with you']
# category: joy
# message: ['live you sure you dont necessitate to escape the applicationjava first Note that this embody a 100 clean install']
# category: fear
# message: ['ahahahaha ikr maybe its utile for perform bullet lists surgery indicating status of something']
# category: joy
# message: ['information technology doesnt work for groovy still']
# category: sadness
# message: ['sry for postulate small stuff like that just until i get a good grasp on the source filing cabinet and abilitiesunits its easier to inquire than to expend 15 minutes search P']
# category: sadness
# message: ['deuce there doesnu2019t seem to be any way to use transforms in conjunction with it I donu2019t very understand how transforms work on Cucumber JVM merely thatu2019s what people told me which would help give you more flexibility']
# category: fear
# message: ['The campaign make up uber hardcore information technology implied low stratum units with low amounts of price so 12 points or so']
# category: sadness
# message: ['JSF is upright']
# category: joy
# message: ['thats not extremely of import to embody shown there']
# category: anger
# message: ['hey guysnI am fresh in cucumber but I need to habituate thiscucumberjvm appium in my project I installed all this stuff and dont know what to do I general I interpret but in my project some programmer spell some code and in that respect a lot of classes I confused Can somebody explain this or at least send me some helpful articles Ane read a lot but still stuck on thisnThank you very often']
# category: fear
# message: ['trusktr Thank you very often for the writeup I had hop itd be a moment simpler than that too']
# category: joy
# message: ['Whats the value of a trial result if the test fail intermittently and possess to be run respective times in rescript to pass']
# category: anger
# message: ['alright cross you fingerbreadth then if only for this power i commode probably just apply the activeunit field we were talking about a spell ago']
# category: fear
# message: ['hey btw for eclipse should we keep out scripts folder what if we desire to knead with html and js within Eclipse they do have angular plugin and clobber']
# category: fear
# message: ['But it this change allows you to implement requirefoocss Im all for information technology']
# category: joy
# message: ['yea saw that lashkar e taiba see if I can use it Be Gabilites and Gameabilities the same thing']
# category: fear
# message: ['Look you throw it sound as if IntelliJ be a sucky tool']
# category: anger
# message: ['The Puke for Windows site is looking awesome now 1']
# category: joy
# message: ['So information technology can be use for builds']
# category: joy
# message: ['FF is working online so its emphatically a trouble with my browser when running localhost']
# category: fear
# message: ['and its nice to reckon on the released artefact and only develop and build the things that depend on that above']
# category: joy
# message: ['How do you do guys is there a cucumberjvm arm have the Pickle type Steps from ast']
# category: fear
# message: ['ctrueden sounds good']
# category: joy
# message: ['Mightiness have to do the a great deal uglier And the server is stopped steps for now']
# category: anger
# message: ['hey bozo just a question how hard would be to pivot jhipster to a microservice generator with an optional UI']
# category: fear
# message: ['tukkek if information technology not obstruct dont recall if its coded but we had some corrections to the formula to avert ending up with NaN and have playtest ruined thanks to badly coded effects and scenarios']
# category: sadness
# message: ['no age related macular degeneration plunk for circular dependencies']
# category: joy
# message: ['Which does not put to work for maine because it does not use the javac of the delimitate java8 SDK']
# category: sadness
# message: ['aslakhellesoy hey I flummox sidelined from cucumber for a few days back on information technology now I noticed these step def annotations were removed in master and I be question how they would get implemented in the meantime for my code I exactly made a StepDef annotation that replaces all of them']
# category: fear
# message: ['dont call back thatll study']
# category: fear
# message: ['its direction less code']
# category: joy
# message: ['red cent i detest food poisonings']
# category: anger
# message: ['mikolasw not Cucumis sativus related sorry']
# category: sadness
# message: ['maybe if someone made a first person view for mobas that would really put you in on the action but idk any that be like that actually i saw one federal protective service moba formerly merely it wasnt that dear not even when compared to the classics']
# category: sadness
# message: ['tukkek endeavour to change Zephyrum avatar by force just fails']
# category: sadness
# message: ['Were going to be badly bandwidthconstrained as well be but deuce citizenry and the company be starting kicks off Oct 1st']
# category: sadness
# message: ['So Im still working out the kink at that place like I think I crap my ain branch on my fork but its not showing up on git for we reason Ill google all that poppycock and get it up after I can clear my mental cache from this bit of refactoring Im working on']
# category: sadness
# message: ['Information technology always take 2 days for a bout of communication']
# category: sadness
# message: ['Squareys Sorry to find out that Mars hold problems But thanks for the oral sex up I was just about to switch after hinerm said things were work well for him merely we didnt test code clean up']
# category: sadness
# message: ['yes urgently']
# category: anger
# message: ['iodine used KNIME <url> for that its free opensource and awesome but One might embody bias Viosterol']
# category: joy
# message: ['oh thats squeamish']
# category: joy
# message: ['SimonKaz Im also middling new to Git and contributing to OpenSource be doing my own thing on Subversive activity for far far too long']
# category: fear
# message: ['hm hard to answer some PRs in Ops be pending because of the ThreadService issuing in SciJavaCommons and the germ in ImgLib2ROI Anyway I will let you know tomorrow if I remember information technology super urgent okeh']
# category: sadness
# message: ['ha ha ya I would do it to realize a day when your applications be fully autogenerated from a base mannequin']
# category: joy
# message: ['so how can we make that let pine tree state upload my sample code']
# category: fear
# message: ['Be in that location a way to pass one extension through many plugins Corresponding middleware']
# category: fear
# message: ['the update crataegus oxycantha non have cleared the cache so may have postulate an install atomic number 9 to work']
# category: fear
# message: ['it work out D']
# category: joy
# message: ['on that point be a moba made for tablets and supposedly optimize and bs but the guys in the trailer exist tapping the pad of paper projection screen like fucking morons you would guess the cracking in no metre']
# category: anger
# message: ['luckily given that its entirely one test information technology should follow relatively easy to fix']
# category: joy
# message: ['i reckon the alone way i can make this workplace right now is if the sideboard be only execute when the stateless person takes some damage would that be ok for now']
# category: fear
# message: ['sorry I detect the ascendant causenIs there any information when it could be fix']
# category: fear
# message: ['Thanks yet again Ailment hear your mesmerism now']
# category: joy
# message: ['difficulty is information technology is non just the formatting']
# category: fear
# message: ['and reading through be very hard']
# category: sadness
# message: ['Zephyrum yeah constantly consider of that but current engine doesnt coiffure 3d which will be ask xD so Im guessing there will be a port eventually']
# category: sadness
# message: ["dietzc Sorry Ace missed you in imagejdev yesterday I be home sick and by and so I had passed ko'd"]
# category: sadness
# message: ['Thanks guys']
# category: love
# message: ['woot nice']
# category: joy
# message: ['not indisputable some of the course of instruction namings piss me off naughtily']
# category: anger
# message: ['yes on the button theres an number trailing that']
# category: fear
# message: ['Is anybody familiar with the direction the Keyword annotating are pop off in Presumption When And so etc']
# category: fear
# message: ['works easily with cucumberjvm also']
# category: joy
# message: ['I would need to make a fresh repo for the samples']
# category: sadness
# message: ['breeze through it']
# category: joy
# message: ['but if this estimation 1 sustain leave work hopefully it will information technology means that it be only a result for this ability plasma field and not to all counterlike abilities']
# category: sadness
# message: ['guybedford This user that get the pace boundary erroneous belief from GitHub is also state they get information technology on Mac as wellu2026even after they have configured it with their certificate Any ideas']
# category: fear
# message: ['Which again stand for that IDEs wouldnu2019t be able to report results nicely']
# category: sadness
# message: ['If only 2 people ever so edit a wiki that make up a signaling that non everybody need to participate']
# category: sadness
# message: ['code looks in force will do exam tomorrow will have to combine first in all probability regardless']
# category: joy
# message: ['yes with angular too information technology is not directly working']
# category: sadness
# message: ['Zephyrum haha that was the hooey I be talking about regarding the article I should write the left side and right side corners have different number of adjacent tiles Ane think that on the left over side the unit in corners live more protected against melee aggressor as less units force out meet near them']
# category: joy
# message: ['its something ive make up planning to execute equally well let me lie with if you attain any progress']
# category: love
# message: ['We need someway to allow author to create ecosystem builds for their existing components Non only the new that are written in ES6 format']
# category: fear
# message: ['in reality Im gonna experience drunk and leave practice that tomorrow today was a long twenty four hours haha']
# category: joy
# message: ['Im to a greater extent interested about existing plugins than ES6 transcompilation']
# category: fear
# message: ['ctrueden thanks for replying Actually what One want to do is subtract background from an image and filter disturbance and then use threshold algorithm to detect areas of pursuit in the image I dont require it to be a client side application Just need to perform these tasks on an figure Is this possible Could you please manoeuvre me on how to proceed Thanks']
# category: fear
# message: ['ctrueden hinerm nndoes the contented assist work for groovynnspeaking of groovy the following codification does not work because ArrayList is not converted Iodine bottom work around it expend the Dimensions interface but it would be gracious to be able to use the concise call in the workshop nn OpService opsnnopscreateimg2020n']
# category: sadness
# message: ['I withdraw be able to get it into a confused state where former menus also wouldnt workplace just not the details and my memory board whitethorn constitute wrong']
# category: sadness
# message: ['yeah ive tally tags and removed those trial from independent suite I very need them ply though']
# category: sadness
# message: ['not sure if youve gotten to the dep shot part']
# category: fear
# message: ['yes but what to coiffure after ctrl enter and so type bacon']
# category: fear
# message: ['UMD is a prominent fail']
# category: anger
# message: ['hey guys anyone facing issues melt gatling on window with gradle']
# category: fear
# message: ['but yeah Gradle seems sketchy as fuck especially with Windows']
# category: anger
# message: ['just users ended upward preferring paths as it was what they expect']
# category: sadness
# message: ['aslakhellesoy Im not seeing any advantage to TreeMap over HashMap in RuntimeGlue TreeMap would be useful if ordering was necessary but I dont see any need for regularize here TreeMap access be Olog nitrogen and HashMap access comprise O1 we could see astir a 10x addition in speed while accessing StepDefinitions if we switched']
# category: anger
# message: ['hahaha im loving it DreadKnight okay this displace be changed later as well i was just wondering if single did my math unseasonable']
# category: joy
# message: ['Nice I asked about the mailing listing because I reckon more people could postulate more questions plowshare some thoughts help each early Twitter is too restrictive github exit too stately and Ive seen people losing credibility on stackoverflow because of nothing But I got your point this might be helpful enough Thanks']
# category: joy
# message: ['Some of the tutorial personify not really runnable from Playscript Editor Eg the novel module preprocessor plugin']
# category: sadness
# message: ['ha hour angle ya thus is your gulp failing instantly']
# category: joy
# message: ['Just I perform not know how to hold coexist the deuce versions one for triad and another for four in the same trunk without duplicate code']
# category: sadness
# message: ['but it didnt capture the fourth dimension disputation']
# category: fear
# message: ['but exactly one hp theres some randomness in Homm3 collision arent incessantly the same how does that piece of work xD']
# category: fear
# message: ['Zephyrum woot so i need to start with to mention someone same on chirrup fb']
# category: sadness
# message: ['Yup NPM rocks especially if u expend a gruntgulp plugin that does the major minor motorcar protuberance and git commit tag and npm update everything in unrivaled step is so neat you should consider practice those as well for your ain workflows']
# category: joy
# message: ['As a side noteu2026if thereu2019s any way to not utilise the github api and instead use browser connection I think that would make thing nice Another recommendation is to make the warning about github credentials a bit more obvious I notice that people are miss that']
# category: anger
# message: ['aslakhellesoy also I have some problem that Ace cannot loose feature article file in my Android Studio']
# category: fear
# message: ['Im also referring to the deep red effectuation wherever potential to mirror some of that Not so great at crimson so information technology more of a guideline than anything for maine']
# category: sadness
# message: ['Hi all Single screw the mind of jhipster and have played with it a bit only Atomic number 53 have some concerns about it and would like to see your legal opinion of them']
# category: fear
# message: ['Flavor similar a wrong version of the Java electrical engineering APIs']
# category: sadness
# message: ['volt ampere computer code thank younnn nnn']
# category: love
# message: ['the edit feature hither is pretty nice deficiency of eternal rest makes me a bad typer P']
# category: joy
# message: ['I never examine JSF P']
# category: sadness
# message: ['but do we have to manually key in thedist way of life']
# category: fear
# message: ['fair plenty']
# category: joy
# message: ['thank you checkmate']
# category: love
# message: ['Im trying to install Leaflet which currently fails due to 289 I dont understand the workaround mentioned there though The workaround is to add ignore debug to the packagejson override All Iodin could find about override be the registry which seems to host a clump of packagejson overrides But how can I do that locally in my own projects packagejson for Leaflet']
# category: sadness
# message: ['ctrueden Iodine cannot use ScriptEditorTestDrive for <url> It cannot procreate the bug']
# category: fear
# message: ['trusktr thanks for looking into the wiki update']
# category: joy
# message: ['all mark with one failure D']
# category: sadness
# message: ['The documentation at that link doesnu2019t quotation the u201cregisteru201d format as an choice or that information technology personify ask for right install of cash register faculty libraries']
# category: surprise
# message: ['aslakhellesoy thanks Im wondering if anyone have lick the problem of testing Angular apps from Java nBTW love the Cucumber vine playscript']
# category: joy
# message: ['but you cant over match exact semantics']
# category: sadness
# message: ['Can any body serve me how to create an workable jar out of cucumbermaven task']
# category: fear
# message: ['Seems a routine weak to me Itu2019s a shame we havenu2019t had any PRs about this but Single guess a lot of our enterprisey user just donu2019t consider doing that beaver state arenu2019t allow to while at piece of work']
# category: anger
# message: ['No Im wrong']
# category: sadness
# message: ['Your tests be trying to tell you something']
# category: anger
# message: ['precisely']
# category: joy
# message: ['o.k. it be my fault after all']
# category: sadness
# message: ['Is that unspoilt plenty']
# category: fear
# message: ['guybedford Artium magister I supposed to put registry jspmu201d in packagejsonu2019s jspm theatre of operations if the package volition be installed from github']
# category: fear
# message: ['Decently now our handling of multicomponent images in MicroManager be pretty unpleasant theyre split up into practical channels for display on the ImageJ side']
# category: sadness
# message: ['btw the abolisheds drafting be so fabulours i slant handle it haha but look at it all flaming and stuff']
# category: joy
# message: ['then one found the dist folder is miss indexhtml']
# category: sadness
# message: ['Im not indisputable what values of deps be supposed to mean']
# category: fear
# message: ['honest']
# category: joy
# message: ['single found a discussion on this topic but 1 pitch get hold any resolution to it <url >']
# category: sadness
# message: ['Fault getting parcel config for githubjspmnodelibsprocess Unable to control repo packagejson for release position code 401 Any ideas']
# category: fear
# message: ['Yeah require Java eight was a in particular wretched pick from a collaborationcooperation point of view']
# category: sadness
# message: ['hunky dory thx for the info']
# category: joy
# message: ['but appear likewise much work and a routine too early to get to know all the parameters involve']
# category: sadness
# message: ['i saw a fleck of that just mostly a code organization issue non a design trouble anyway hardly my first impression of the codification base looks pretty decent to me yet with that']
# category: joy
# message: ['iodine need some interim solution for now though be hope for the skip test option']
# category: sadness
# message: ['but that could get first rate annoying']
# category: anger
# message: ['there used to be gimpy setting with miserable time pool oregon just a few plasma point pools not utile for real gameplay but useful for test so']
# category: sadness
# message: ['But I personally do non own time to coif that As Johannes says changes along those lines would greatly benefit the community']
# category: sadness
# message: ['Information technology would exist nice not to hold to care about credentials guybedford Any conceivable way to arrange that npm seems to work without a hitch but github gives issues']
# category: fear
# message: ['if I exchange p the exportation value changes']
# category: fear
# message: ['Another interrogative sentence after starting the application I didnt check overnice styled web page like in tutorial stake here <url> Is information technology a glitch count on compass libraries']
# category: fear
# message: ['which doesnt documentation that']
# category: sadness
# message: ['Wherefore it cant mint with already existing snapshot newton']
# category: fear
# message: ['thanks that makes sense so we should always support it because requiring users to make caboodle of freestanding packages for freestanding functionality become impractical at some level when want to make extremely modular libs']
# category: joy
# message: ['but I think it ugly']
# category: anger
# message: ['O.k. thanks for the info And skillful luck with everything sounds like you throw a busy calendar month ahead of you']
# category: joy
# message: ['vent asset not releases how']
# category: surprise
# message: ['yes dynamical loading is bonk']
# category: anger
# message: ['if we can nail that gloomy that would equal thus coolheaded']
# category: joy
# message: ['Energy department npm use apigithubcom Atomic number 53 never see rate limit point warnings from npm']
# category: fear
# message: ['Information technology perhaps more of a webdriver issue just wonder if anyone else have had and puzzle out a alike problem']
# category: fear
# message: ['EisenbergEffect great so you didnt need to localize the custom config any longer']
# category: joy
# message: ['Solved thanks anyway']
# category: love
# message: ['But I cant receive anything about information technology in ES6 swig <url >']
# category: sadness
# message: ['also there cost strong lay away']
# category: sadness
# message: ['thanks bro']
# category: love
# message: ['from what Ace rear end see be not inject the data into the html merely thats strange because I cant even return the report without the JSON file with the data that it needs to inhabit the actual report Im so confused']
# category: fear
# message: ['some of the Abolisheds ability cryptography could pay back cleanup for certain lots of nested if statements that arent even command anymore legacy logic']
# category: sadness
# message: ['I really alike jHipster the community behind information technology seem fun Im gonna try to sting around and contribute']
# category: joy
# message: ['Im having problems printing reports on Cucumber vine JVM']
# category: fear
# message: ['Major progress on the ImageJ OPS builtins branch concluding dark']
# category: joy
# message: ['Thats very chill astir the silver plan for academe']
# category: joy
# message: ['so its a hemipteron i speculation']
# category: fear
# message: ['Lad my interrogation still goes unresolved']
# category: sadness
# message: ['Iodine cant test it as I dont have SQL Host']
# category: sadness
# message: ['deepu105 I cause my window machine at the office and have a short holiday until wednesday So Iodine cant over check information technology simply Ive never tried it on windows']
# category: sadness
# message: ['appium be pretty much se so its refreshing']
# category: joy
# message: ['no point working with flaky avail']
# category: anger
# message: ['Hi ways any of you live how to use cucumber vine in a playframework project scala']
# category: fear
# message: ['welcome']
# category: love
# message: ['thanks Complaint check it taboo']
# category: joy
# message: ['1 think so too alright hemipterous insect report']
# category: sadness
# message: ['Does that work on i was getting some eldritch exceptions']
# category: fear
# message: ['Its AMDs require that doesnt']
# category: sadness
# message: ['ass xhtml forever']
# category: anger
# message: ['operating theater does it create a new objective every time likewise']
# category: fear
# message: ['only yeah it not easy at the consequence']
# category: fear
# message: ['iodin can only verify that during a test']
# category: sadness
# message: ['It seems its a critical issue Might be enough to add if srcClass void takings false to AbstractConvertercanConvertConversionRequest and if src void replication false to AbstractConvertercanConvertClass Class Though the NullConverter might then need to override more than canConvert methods too']
# category: fear
# message: ['My ain fault I changed an input field into textarea']
# category: sadness
# message: ['seems youre better at this compared to me']
# category: love
# message: ['Zephyrum as a history buff that you be youll in all likelihood get laid the eventual Kingdom Wars AB mode']
# category: joy
# message: ['just cling']
# category: fear
# message: ['Would rattling appreciate']
# category: love
# message: ['Doe anybody get a hint how to just add a custom angulate route quickly I stress to use angularfullstack generator but it seams that JHispter is using the same complex body part only non the plugin']
# category: fear
# message: ['i really hate XML Phosphorus']
# category: anger
# message: ['ive scarcely create a new undertaking using jspm v0103 im importing a file but for some reason its not transpiling ES6 to ES5 i just stupefy an error']
# category: fear
# message: ['that would be awesome one think the design be already middling good for a gamepad huh i wanted to add gamepad support for javelin but there personify hence many commands its non really possible']
# category: joy
# message: ['fine found the solvent <universal resource locator >']
# category: joy
# message: ['And doesnt crop it']
# category: fear
# message: ['Welcome backward']
# category: love
# message: ['Does someone sleep with how to integrate spoonful and cucumber']
# category: fear
# message: ['Yes Ill put this feature in BETA anyhow so hopefully information technology wont demote too many things']
# category: fear
# message: ['Bevel say i be wait that to be so inyourface sorry']
# category: sadness
# message: ['for the overrides Im non sure Single understand why you need to override your own repo though']
# category: fear
# message: ['Thanks for the adviceu2014I will file away an issue for it']
# category: joy
# message: ['Oh yes Ive found jspm on gitter what an awesome touch']
# category: joy
# message: ['There equal destiny of advantages to that besides']
# category: joy
# message: ['Ill bring back to work so close to running pickles']
# category: joy
# message: ['I nearly might have to fare that first actually I am getting paid by somebody to produce issue so I kinda need to beget a solution out the dooreven if impermanent sometime in the adjacent few clarence shepard day jr.']
# category: fear
# message: ['awesome']
# category: joy
# message: ['that be an authless apigithub petition']
# category: anger
# message: ['oops do gulp ramp up']
# category: fear
# message: ['yes same offspring information technology works but throws weird errors']
# category: fear
# message: ['decent because way back Abolishes passive was doing damage all around when in reality receive damage thus 2 Abolished next to each early stimulate issues']
# category: sadness
# message: ['Everyone FYI a horrible Updater microbe hit ImageJ today causing the jarsimagej200rc30jar file to vanish from the Fiji continuous release Iodin repaired the update situation and am hop the following discharge build presently in progress <url> does not suffer this problem anymore']
# category: fear
# message: ['tukkek deploy yeah sorry typed path by hand']
# category: sadness
# message: ['aslakhellesoy thank you man really much Iodine understand']
# category: love
# message: ['lots of potential']
# category: joy
# message: ['Would hump to hear feedback on this should all packages allow requirepkgsubmodule Or could we restrain all packages to only break primary']
# category: fear
# message: ['serious news']
# category: joy
# message: ['yea Im non 100 sure its cracked up to work with cucumberjvm because its such a foreign usecase for JUnit']
# category: fear
# message: ['Erroneous belief download githubjspmnodelibstty Badness response codification 406 With authentication back on']
# category: fear
# message: ['and I have next head astir sendKeys does this method sustain some restriction']
# category: fear
# message: ['Like event here with Holy grail <url >']
# category: sadness
# message: ['I embody playing a scheme secret plan EU4 correctly now and the protestant reformation scarcely started in Transylvania somehow']
# category: surprise
# message: ['skilful Im confident youll manage hes well nigh used after all so its important xD']
# category: love
# message: ['Well Im a sucker Iodine pushed the push']
# category: sadness
# message: ['appiums great']
# category: joy
# message: ['I donu2019t know gradle']
# category: sadness
# message: ['seiyria Way to bolt down the vibe youre free to leave if you need Im new to gitter and it suggested me people probably that starred the project on github and mightiness be interested in it When I clicked add on someone it said that he was invited so that sounds like something that has to be approved manually to pine tree state Sorry for your inconvenience thanks for your feedback']
# category: anger
# message: ['No javacjar found look in UsersjanoschApplicationsFijiappjars']
# category: fear
# message: ['defective']
# category: sadness
# message: ['dscho Sure no job']
# category: joy
# message: ['tally auth gives a 400 wrongdoing']
# category: fear
# message: ['industrial plant on maven']
# category: joy
# message: ['this whitethorn be an update issuing']
# category: fear
# message: ['but also the settlement cognitive process']
# category: fear
# message: ['trusktr thats awesome youre getting together an instance that works in all environments']
# category: joy
# message: ['shouldve shell the cash out of my rescue']
# category: sadness
# message: ['Hi guys Ace bear some entity which work amercement in dev mode just after the oink compression some of them betray Which live the best stead to start to fix this']
# category: fear
# message: ['And felicitous Superintendent u03c0 day Information technology already passed hither not the entire clarence day but 92653 am']
# category: joy
# message: ['gladiola to have it off no one will get to go through this suffering']
# category: joy
# message: ['websocket doesnt body of work though']
# category: sadness
# message: ['alright appear to make up done']
# category: joy
# message: ['sounds like information technology could give been minor upgrade of the endpoints autoflush the memory cache but this bug fix didnt include a cache bump I belike should birth included this']
# category: sadness
# message: ['a lot of lowly bug like that which need to be crush in order to get things back on cut suspiration']
# category: sadness
# message: ['Complaint stick with jhipster 2X thanks Cheers for the contact though']
# category: joy
# message: ['Yep smile Information technology represent fixed about 5 hours ago']
# category: joy
# message: ['non trusted if its a windows issue']
# category: fear
# message: ['comprise still in teethe']
# category: sadness
# message: ['ok thanks will try out that']
# category: joy
# message: ['I just give a endeavor to angularfullstack but you can not scarce add a route without creationg a wide cut practical application and this be non the qucik sportsmanlike easy solution i need Will try angular']
# category: sadness
# message: ['just the js is form operating theater irrelevant here']
# category: sadness
# message: ['Its so sluttish its precisely insane']
# category: joy
# message: ['interesting but on line games are soft to cheat wed have to make trusted cheating is very gruelling to do']
# category: fear
# message: ['What does information technology intend when jspm install spits back a 406 Bad Reaction Getting this from several github repos exactly curious about information technology']
# category: fear
# message: ['How do you do everybody I am get some problems with the imagej codestyleformatterprefs for eclipse It appear that imports are reorder in DefaultOpService for illustration and T implements be format to Timplements I be using Eclipse Mars which may live the issue']
# category: fear
# message: ['yeah hard to imagine a moba played with optic for case unless youre simply using information technology as an alternate screen that is impound to your face']
# category: anger
# message: ['Now 1 need to persuade people to information technology']
# category: anger
# message: ['yep the pamphlet is still in that respect with a hunky dory looking ace project']
# category: joy
# message: ['MM20 be such a radical restructuring though that I hold to have opportunity where possible to simplify']
# category: sadness
# message: ['Itu2019s a fairly big task to refactor CucumberJVM to utilize Gherkin3 brasmusson do information technology for CucumberRuby I have a offset on CucumberJVM that started the work only in that location comprise yet lots to perform']
# category: fear
# message: ['haha all in all Hippie thing and all Im really happy I found this I use Angulate in essentially everything I do that experience anything to do with Front terminate design']
# category: joy
# message: ['DreadKnight wonders how to get nickname autocompletion around tab key non working hmm']
# category: fear
# message: ['but yes completely contrary to the webpack point of sight']
# category: sadness
# message: ['That should personify OK so']
# category: joy
# message: ['Hey porting jHipster to MS SQL and writing a pathfinder along the way Sadly slenderly stuck anyone thinks they keister figure out how to fix this error <url >']
# category: sadness
# message: ['if somehow i push that into the rootage computer code by mistake it would be a huge problem']
# category: fear
# message: ['I donu2019t like having to ingest a shell playscript though The job with leaflet be information technology doesnu2019t use modules It relies on npm instal to build up into a single globular faculty Jspm isnu2019t handling that']
# category: sadness
# message: ['And so AMDs define supports orbitual dependencies']
# category: joy
# message: ['Right now Im seek to get my profile picture I did change information technology but it withal shows maine the default nonpareil']
# category: sadness
# message: ['simply information technology changes a lot of stuff in the template']
# category: fear
# message: ['im rattling new to gradle so dont know how to do that to override for gatlingrun task if you could give me a pointer 1 can strain that out and if successful can practice a PR']
# category: fear
# message: ['well its an onetime secret plan']
# category: sadness
# message: ['Checking other peoples artifacts into SCM is so 1995 and non really hipster at all']
# category: sadness
# message: ['If you are look to call ImageJ1 plugins then it testament constitute nighimpossible because ImageJ1 is real tightly couple to AWT which be non uncommitted on Android']
# category: sadness
# message: ['When I dig into the jspm generate code it looks comparable maybe jspm is obscure and is writing come out some commonjs stuff']
# category: sadness
# message: ['I am pretty sure this is non still valid english phrase structure']
# category: anger
# message: ['if I suppose astir it leave too do damage to organic attacks which are considered melee attacks with range in some way']
# category: fear
# message: ['yea i guess if mesh play is ready the bradypus tridactylus is not that crucial anyway do you guys have any musical theme how to print a variable value for debug pruporses windowalert doesnt seem to work']
# category: fear
# message: ['its just not coif anything']
# category: sadness
# message: ['in any case iodine make out what youve exercise it give maine a singlehanded chance at doing a entire fledged web app for my project']
# category: joy
# message: ['atomic number 53 detest them too']
# category: anger
# message: ['Zephyrum havent really played any of the civilization games myself so many skilful old schooltime games mention today that I havent extend to only researched']
# category: sadness
# message: ['i really wont have fourth dimension to do that tomorrow but possibly next week its a unproblematic matter but helpful only gotta trope out how to do it properly']
# category: sadness
# message: ['I lost rather a few beer vs him had to put a pileus and try to bring in back some of them']
# category: sadness
# message: ['only i guess im quick to try and inscribe some of those ascent now']
# category: joy
# message: ['guybedford Or is it only have in mind for command line of reasoning overrides And should information technology equal in the jspmregistry override I think machine setting of this would alleviate mix up']
# category: fear
# message: ['Peradventure I dont understand something']
# category: fear
# message: ['Less oeuvre for me']
# category: joy
# message: ['yeah the method acting Creaturetakedamage has a ignore retaliation argument so its clear that something suffer been do like this but idk if its exactly what i need hither']
# category: fear
# message: ['So I fear lots of user bug report be going to fall by the wayside for a patch interest']
# category: fear
# message: ['Thanks Ill try to debug this on JS layer to examine what is happening']
# category: joy
# message: ['simply fourth dimension is a big constraint']
# category: sadness
# message: ['EisenbergEffect in reality that english hawthorn not be a fix']
# category: fear
# message: ['oops haha Opinion I was at the command agate line']
# category: joy
# message: ['o.k. got the latest fire up here metrics work java jar targetwar on my local amd64 Ubuntu box only non on my server with the same war in i386']
# category: fear
# message: ['Im porting existing RequireJS applications programme and it twist out each course entry really means two things Eg foo componentsfoo actually means foo componentsfoojs foo componentsfoojs']
# category: fear
# message: ['Because on server CJS is standard theres no job']
# category: joy
# message: ['Hello Iodine question why directory bowercomponents isnt mention in gitignore file so that iodin wont comprise versioned']
# category: fear
# message: ['Maybe some radio link']
# category: fear
# message: ['ctrueden sorry I escape this Would you be available to meet at 400 eastern300 central Or later in the calendar week if that doesnt body of work']
# category: sadness
# message: ['thanks for pushing to ready thing easier']
# category: joy
# message: ['yeah but i yet be missing the finishing step']
# category: sadness
# message: ['this be confusing to pine tree state Ane can see why frontend would care to have its own server raft but to pine tree state the unhurt architecture seem to be a recipe for problems']
# category: fear
# message: ['my book of job as an automation engineer follow to make e2eui tryout']
# category: sadness
# message: ['omg bbq One cant get quotes to work same that for me nnI scarce click on the Quote old world chat option']
# category: fear
# message: ['was in the beginning an electrical engineer pleasure']
# category: joy
# message: ['aslakhellesoy some squad members are suggesting using CucumberJS Iodin opine that would mean either having multiple trial suites operating theatre losing a just amount of investment funds in Coffee']
# category: fear
# message: ['So we do scores of lazy init stuff in many services']
# category: sadness
# message: ['i have an extraneous service that SOMETIMES is down also often for my gustatory modality']
# category: sadness
# message: ['haha and they dont build']
# category: joy
# message: ['I just gave the opportunity to cucumberjvm again only for me is really really important that the tryout can execute in parallel Most of the trial be e2e wether theyre loading a webdriver instance or attacking an API Switching to jbehave after explore a fleck I think Ailment find greener field of battle there']
# category: sadness
# message: ['JHipster 2120 comprise under style']
# category: joy
# message: ['stage taken on making this process soft though']
# category: joy
# message: ['yes I estimate Iodine was still following the dream and so of everything being a module epithet']
# category: sadness
# message: ['all dissimilar']
# category: fear
# message: ['yeah the SF timezone isnt apotheosis from hither']
# category: sadness
# message: ['merely as far as you cost unspoiled so be your pom']
# category: joy
# message: ['I think it needs a jolly large refactor to accomplish though']
# category: fear
# message: ['I may convert some Coffee examples only to scripts Still cogitating The UsingOps example be still a botheration in Coffee due to lack of sufficient typesafe method signatures']
# category: anger
# message: ['omg bbq I pitch get quotes to work like that for maine']
# category: fear
# message: ['yo jhipster doesnt arrange g install as far as I know']
# category: sadness
# message: ['like this Five hundred']
# category: joy
# message: ['i genuinely like the concept of writing computer code that writes your computer code joycat']
# category: joy
# message: ['Yeah will be happy to be backward']
# category: love
# message: ['Tons of work to get along still']
# category: sadness
# message: ['it would be really worry to share the setup youre practice to stick out all systems']
# category: joy
# message: ['cool Ive recently got into a tendency to habituate dark report wherever possible']
# category: joy
# message: ['yeah im not complain scarcely commenting on it also if ace get more experience with the codebase maybe it would have taken only 23h indeed']
# category: sadness
# message: ['but support doesnt look the correct lieu coz documentation otherwise talks astir using what is bundled in the generator and tips and trick is about apply external plugins and stuff religious rite']
# category: fear
# message: ['it non working code just pseudo codification']
# category: sadness
# message: ['After initializing my labor with jhipster when my collegue puff it hes face a table already be with liquibase What is wrong']
# category: fear
# message: ['What happen when you load AMD CommonJS module with Systemjs']
# category: fear
# message: ['as well how are you supposed to defeat a actor if the plasma shield prevents any wrong from being done im taking some metre to check tabu the creatures and magnate straight off']
# category: fear
# message: ['Hello guys need a helpI need to call the run my featute file by calling the cucumbercliMain flesh a java class by passing the the parameters like tag formatI its possibleI don need to practice cucumber options as I birth to pass the tag name s as a variable']
# category: fear
# message: ['Hi I only startle valuate jhipster and comparatively new to Yeoman One am planning to employ Oracle database What is the good way to go astir information technology Source doesnt support Oracle yet so is there a way to skip the database part']
# category: fear
# message: ['Perfect tense I be imagine the same thing scarce getting through my dinner party before commenting']
# category: joy
# message: ['so Im a little stuck here']
# category: sadness
# message: ['on tom 8 my war form excessively']
# category: joy
# message: ['ya still im used to xmlbut dont similar it Phosphorus have personify doing lots of soap services sooner so i get tired of xml']
# category: sadness
# message: ['dscho It seems that Google Code shut its room access yesterday Several jobs character reference itnn grep codegoogle jobsconfigxmlnjobsFijisynchronizerconfigxml <url> njobsImageJAsynchronizerconfigxml <url> <url> <url> <url> nnWould you agree that I should remove those repos from those problem']
# category: sadness
# message: ['oh ya windows worry']
# category: fear
# message: ['deepu105 Iodine love you to last']
# category: love
# message: ['Complaint take a looking thanks']
# category: love
# message: ['Were not at a place yet to specify these workflow unluckily']
# category: sadness
# message: ['which I could understand lol']
# category: joy
# message: ['gab1one Buckeye state yeah poise']
# category: joy
# message: ['rishabhsethi Non yet as an end substance abuser application But much groundwork comprise done with the ImageJ2 projection to facilitate a future Androidbased interlingual rendition']
# category: sadness
# message: ['Yes ditching Coffee 6 is go to solve a lot of job']
# category: joy
# message: ['so i dont think ace can mock that single and leave the rest']
# category: fear
# message: ['the work around would be i involve to pass variables to each office song which atomic number 53 guess really high risk approach']
# category: fear
# message: ['it really isnt that hard it just sustain a lot of weird ass detail you gotta nail differently itll hardly flunk']
# category: sadness
# message: ['But thats loading stuff Cant you utilize AMDstyle defining and utilisation Systemjs for orbitual addiction support']
# category: fear
# message: ['Ive noticed that it gravel quite popular some courteous projects are making really good employment of information technology and Im start to like it as well']
# category: joy
# message: ['So their could maintain their own RunWith configurations and then simply add the Rule to the Test Category meant to equal run this is where things fetch a little weird and maybe impossible for cucumberjvm to do information technology']
# category: fear
# message: ['aslakhellesoy yes take away cucumberjava from the classpath fixes that issue Thanks']
# category: joy
# message: ['I dont see whats wrong with the extra typeing though']
# category: anger
# message: ['the guy world health organization coded it is quite amazing hes a really smashing creative person and require to pursue that path so hell be able to riposte a routine after on when the focus be primarily on eye candy and animation']
# category: love
# message: ['1 think I fix him a little fire up and energizedu2014not sure if he took any of that book binding to you guys']
# category: joy
# message: ['For context Fortunate sufficiency to suffer a dedicated DB somebody this project so Ailment just go ahead and create all the entities with the jHipster peter so One do get the awesome code generation then manually represent the Table and former Hibernate variable']
# category: joy
# message: ['alright id have to see how information technology programmed then but rly if you call up id be a ripe asset for the team id ask you to start working on that networking code asap we could use it for the undo and replay features as advantageously']
# category: joy
# message: ['And then it plays out with historical hooey and thus on empires potent at the time like France and the turks tend to grow quickly while country world health organization fell similar the byzantine imperium dies early on however this game always finds a way to screw up history and receive something stupid happen xD']
# category: joy
# message: ['Sure if you like I am all right either direction']
# category: joy
# message: ['but yeah that character boundary for filepaths can be horrible']
# category: fear
# message: ['considerably if you want my help id be glad to kick in it hold a lot of sport today plus ane recollect the game can get truly good']
# category: joy
# message: ['Its not a show stopple The script still functions I exactly cant over make a exhibit when creating the new ImgPlus with meta data point']
# category: sadness
# message: ['Completely understood and I sympathise']
# category: love
# message: ['operating room coexist more than easily']
# category: fear
# message: ['Ah because information technology hasnt been finished heretofore']
# category: sadness
# message: ['And as a incentive Ailment not yet bug you about community and participation any longer']
# category: joy
# message: ['Id constitute more OK with information technology if the raw materials were stored in something and exactly used during the build to assemble something working']
# category: sadness
# message: ['im still kick back myself for not going']
# category: sadness
# message: ['They often donu2019t know or realize']
# category: sadness
# message: ['hinerm Behold <url >']
# category: joy
# message: ['age related macular degeneration for browsers is difficult to fence these years']
# category: sadness
# message: ['I understandu2026trust maine']
# category: sadness
# message: ['ane think i tried all the potential options already']
# category: sadness
# message: ['And if you publish something to NPM information technology stays in that respect forever']
# category: sadness
# message: ['1 it doesnu2019t look to call the builder or even instanciate final fields which be a bit of a pain']
# category: anger
# message: ['Is at that place any way to do intellij show colored output like not monochrome']
# category: fear
# ...
# message: ['If you are looking to call ImageJ1 plugins then it will live nighimpossible because ImageJ1 is rattling tightly coupled to AWT which be not uncommitted on Humanoid']
# category: sadness
# message: ['When I dig into the jspm generated code it look similar perhaps jspm is confused and be writing out some commonjs stuff']
# category: sadness
# message: ['I be reasonably sure this is not still valid english phrase structure']
# category: anger
# message: ['if I think about it will also make out damage to constitutional attacks which are considered melee attack with cooking stove in some mode']
# category: fear
# message: ['yea i guesswork if electronic network gambling is ready the army intelligence is not that significant anyway do you guys have any idea how to print a varying note value for debugging pruporses windowalert doesnt seem to work']
# category: fear
# message: ['it just not doing anything']
# category: sadness
# message: ['in any caseful i have it off what youve done it gives pine tree state a singlehanded opportunity at doing a good fledge vane app for my project']
# category: joy
# message: ['ace hate them too']
# category: anger
# message: ['Zephyrum havent real play any of the civilization games myself thusly many good old school games mentioned today that 1 havent adjoin only researched']
# category: sadness
# message: ['i very wont have metre to do that tomorrow but perchance next week its a simple thing merely helpful simply gotta figure out how to coif it properly']
# category: sadness
# message: ['I lose quite a few beers vs him had to place a hood and try to earn back some of them']
# category: sadness
# message: ['but i think im ready to essay and code some of those rise now']
# category: joy
# message: ['guybedford Or is information technology only meant for command descent overrides And should it be in the jspmregistry override I think auto setting of this would assuage mental confusion']
# category: fear
# message: ['Peradventure I dont understand something']
# category: fear
# message: ['Less work for maine']
# category: joy
# message: ['yeah the method Creaturetakedamage have a ignore retaliation literary argument so it absolved that something has been done alike this but idk if its exactly what i need here']
# category: fear
# message: ['So I venerate lots of user bug composition are give up the ghost to return by the wayside for a while worry']
# category: fear
# message: ['Thanks Ill try to debug this on JS stratum to see what is happen']
# category: joy
# message: ['but time represent a big restraint']
# category: sadness
# message: ['EisenbergEffect actually that whitethorn non embody a fix']
# category: fear
# message: ['oops haha Persuasion I was at the command line']
# category: joy
# message: ['OK got the latest fired up hither metrics work java jar targetwar on my local amd64 Ubuntu corner but not on my host with the like war in i386']
# category: fear
# message: ['Im porting existing RequireJS application and information technology turn out each paths entry actually means two things Eg foo componentsfoo actually mean foo componentsfoojs foo componentsfoojs']
# category: fear
# message: ['Because on waiter CJS is received theres no trouble']
# category: joy
# message: ['Hello I wonder wherefore directory bowercomponents isnt name in gitignore file so that i wont represent versioned']
# category: fear
# message: ['Perchance some link']
# category: fear
# message: ['ctrueden sorry I missed this Would you be available to meet at four hundred eastern300 central Or afterward in the hebdomad if that doesnt workplace']
# category: sadness
# message: ['thanks for campaign to defecate things easy']
# category: joy
# message: ['yeah merely i notwithstanding am miss the finishing step']
# category: sadness
# message: ['this be fox to me I can assure why frontend would care to have its ain server stack but to maine the whole architecture appear to be a formula for problems']
# category: fear
# message: ['my job as an automation engineer be to create e2eui exam']
# category: sadness
# message: ['omg bbq I cant let quotes to work like that for me nnI merely click on the Inverted comma schmooze selection']
# category: fear
# message: ['was primitively an electrical engineer joyousness']
# category: joy
# message: ['aslakhellesoy some squad members are intimate using CucumberJS Ace think that would mean either having multiple test suites or losing a fair amount of money of investment in Java']
# category: fear
# message: ['So we do wads of lazy init clobber in many avail']
# category: sadness
# message: ['unity have an extraneous service that SOMETIMES is downwardly overly often for my taste']
# category: sadness
# message: ['haha and they dont build']
# category: joy
# message: ['I just gave the opportunity to cucumberjvm again just for maine be really really important that the tests bottom execute in parallel Most of the test are e2e wether theyre loading a webdriver instance or attacking an API Switching to jbehave after researching a bit I consider Ill see greener fields there']
# category: sadness
# message: ['JHipster 2120 is nether mode']
# category: joy
# message: ['period taken on making this process easy though']
# category: joy
# message: ['yes I venture Iodine follow still following the dream then of everything being a module epithet']
# category: sadness
# message: ['all dissimilar']
# category: fear
# message: ['yeah the SF timezone isnt ideal from hither']
# category: sadness
# message: ['but as far as you make up good and then is your pommy']
# category: joy
# message: ['I call back information technology needs a moderately bragging refactor to accomplish though']
# category: fear
# message: ['Unity whitethorn convert some Coffee examples only if to handwriting Still cogitating The UsingOps example constitute still a pain in Coffee referable to lack of sufficient typesafe method signatures']
# category: anger
# message: ['omg bbq I cant buzz off quotes to solve like that for me']
# category: fear
# message: ['yo jhipster doesnt do g installs equally far as Iodine have it off']
# category: sadness
# message: ['similar this D']
# category: joy
# message: ['i really like the construct of writing codification that writes your code joycat']
# category: joy
# message: ['Yeah leave be glad to be rearwards']
# category: love
# message: ['Gobs of work to do still']
# category: sadness
# message: ['it would be in truth interest to share the setup youre using to support all system']
# category: joy
# message: ['cool Ive recently get into a tendency to use dark musical theme wherever potential']
# category: joy
# message: ['yeah im not complaining scarcely commenting on it also if iodin have to a greater extent experience with the codebase maybe it would have take only 23h indeed']
# category: sadness
# message: ['only software documentation doesnt appear the right place coz documentation otherwise talks about using what is bundled in the generator and tips and legerdemain is about using international plugins and stuff rite']
# category: fear
# message: ['its not working codification but pseudo codification']
# category: sadness
# message: ['After initializing my project with jhipster when my collegue pull it hes facing a tabular array already exists with liquibase What be wrong']
# category: fear
# message: ['What happens when you load AMD CommonJS module with Systemjs']
# category: fear
# message: ['likewise how are you presuppose to vote out a actor if the plasma screen prevents any terms from being done im taking some metre to assure out the creatures and powers straight off']
# category: fear
# message: ['Hello guys postulate a helpI want to forebode the run my featute file by calling the cucumbercliMain contour a java form by passing the the parameters like tags formatI its possibleI don want to use cucumis sativus options as Ace have to give the tag figure s as a variable']
# category: fear
# message: ['Hi I just start evaluating jhipster and relatively new to Yeoman I be planning to use Oracle database What is the best way to go astir it Generator doesnt support Oracle yet so is in that location a way to skip the database contribution']
# category: fear
# message: ['Perfective I make up thinking the same thing simply getting through my dinner party before commenting']
# category: joy
# message: ['thence Im a minuscule stuck here']
# category: sadness
# message: ['on tom eight my war works too']
# category: joy
# message: ['ya even im use to xmlbut dont similar it P have been doing lots of easy lay service of process earlier indeed i get tired of xml']
# category: sadness
# message: ['dscho It seems that Google Code exclude its doors yesterday Several book of job reference itnn grep codegoogle jobsconfigxmlnjobsFijisynchronizerconfigxml <url> njobsImageJAsynchronizerconfigxml <url> <url> <url> <url> nnWould you agree that I should remove those repos from those job']
# category: sadness
# message: ['ohio ya windows worried']
# category: fear
# message: ['deepu105 Iodin love you to death']
# category: love
# message: ['Ill take a aspect thanks']
# category: love
# message: ['Were not at a shoes even to delimitate these workflows alas']
# category: sadness
# message: ['which I could empathise lol']
# category: joy
# message: ['gab1one Oh yeah cool']
# category: joy
# message: ['rishabhsethi Not yet as an destruction user application But much cornerstone be done with the ImageJ2 project to ease a future Androidbased translation']
# category: sadness
# message: ['Yes trench Java 6 embody hold up to solve a lot of problems']
# category: joy
# message: ['thus i dont think atomic number 53 can mock that one and leave the rest']
# category: fear
# message: ['the work around would be i call for to pass variable to each social function margin call which i guessing really tough approach']
# category: fear
# message: ['it really isnt that heavy it just has a lot of weird ass detail you gotta nail differently itll just now fail']
# category: sadness
# message: ['But thats loading stuff Cant you use AMDstyle shaping and usance Systemjs for circular dependence support']
# category: fear
# message: ['Ive noticed that it got quite popular some skillful projects are throw really estimable use of information technology and Im start to like information technology as well']
# category: joy
# message: ['So their could maintain their own RunWith configurations and then just add the Formula to the Test Category meant to be pass this cost where things get a picayune weird and maybe impossible for cucumberjvm to do it']
# category: fear
# message: ['aslakhellesoy yes murder cucumberjava from the classpath fixes that issue Thanks']
# category: joy
# message: ['I dont get word whats amiss with the extra typeing though']
# category: anger
# message: ['the guy world health organization coded it be quite amazing atomic number 2 a really great artist and wants to pursue that route so hell live able to rejoin a bit later on when the focus exist chiefly on eye candy and animation']
# category: love
# message: ['I think I got him a little fired upwards and energizedu2014not certain if helium took any of that backrest to you guys']
# category: joy
# message: ['For context Fortunate enough to have a dedicated DB person this labor so Ill just give up the ghost ahead and create whole the entity with the jHipster tool so I dress get the awesome computer code generation then manually map the Table and early Hibernate variables']
# category: joy
# message: ['alright id have to see how its programmed then but rly if you think id cost a good asset for the team id ask you to go working on that networking code asap we could use information technology for the undo and replay features as well']
# category: joy
# message: ['And then it work out with historical stuff and so on empires powerful at the time like France and the turks tend to produce cursorily while nations who fell like the byzantine imperium dies early on however this game invariably finds a way of life to screw up history and have something stupid happen xD']
# category: joy
# message: ['Sure if you care I make up o.k. either way']
# category: joy
# message: ['but yeah that character limit for filepaths fundament be horrible']
# category: fear
# message: ['comfortably if you want my aid i.d. be glad to give it had a lot of playfulness today positive 1 think the game backside get really good']
# category: joy
# message: ['Its not a show stopper The script however functions I just now cant produce a exhibit when create the new ImgPlus with meta data']
# category: sadness
# message: ['Completely silent and I sympathize']
# category: love
# message: ['operating room coexist more easy']
# category: fear
# message: ['Ah because it hasnt been finish yet']
# category: sadness
# message: ['And as a bonus Ill non even pester you about residential district and participation anymore']
# category: joy
# message: ['Id be more fine with information technology if the new materials were lay in in something and scarcely used during the build to assemble something working']
# category: sadness
# message: ['im yet kicking myself for non going']
# category: sadness
# message: ['They a great deal donu2019t know or realize']
# category: sadness
# message: ['hinerm Behold <url >']
# category: joy
# message: ['AMD for browser is hard to contend these days']
# category: sadness
# message: ['I understandu2026trust me']
# category: sadness
# message: ['i intend i tried entirely the potential options already']
# category: sadness
# message: ['And if you publish something to NPM information technology outride thither forever']
# category: sadness
# message: ['1 information technology doesnu2019t seem to call the builder or even instanciate final fields which follow a bit of a nuisance']
# category: anger
# message: ['Be on that point any way to make intellij appearance colored output like non monochrome']
# category: fear
# message: ['let it fail so the commercial enterprise prioritizes fix information technology']
# category: anger
# message: ['Ahh gotcha']
# category: joy
# message: ['addition getting to play the plot with you guys would be a entire winner D']
# category: joy
# message: ['have succeeding problem can someone help men nMessage orgopenqaseleniumremoteUnreachableBrowserException Could not initiate a newfangled session Possible causes are invalid address of the remote waiter or browser startup failurennnnCaused by orgapache <url> Connect to 1270014723 127001 failed Connexion refusedn']
# category: fear
# message: ['everything jailbreak with xhtml']
# category: anger
# message: ['no chrome now it give up the ghost just information technology is still there both busy the spaces and in the turn succession']
# category: sadness
# message: ['jdubois please keep maine updated on the feedback with the SQL Server tip it pretty sketchy it coif work but it plain wyrd']
# category: fear
# message: ['iodine want the host dev to work out out the setuparchitecture for mock server though']
# category: fear
# message: ['Im non sure the benefit outweights the complexity']
# category: fear
# message: ['unremarkably github is real useful for searching']
# category: joy
# message: ['gradle exist tops slow']
# category: anger
# message: ['ok it work with grunt']
# category: joy
# message: ['but ingest to admit gradle initial run is slow as hell but subsequent ones are degraded']
# category: sadness
# message: ['DreadKnight youre in the incorrect neighbourhood <url >']
# category: sadness
# message: ['Hello I tilt campaign jhipster app topically after deploying to Heroku I get an Exception at commycompanymyappApplicationmainApplicationjava72 Caused by orgspringframeworkbootcontextembeddedEmbeddedServletContainerException Unable to start embedded Tom Particular Iodin am using postgress and compass please assist']
# category: fear
# message: ['true its how markdown works leave']
# category: sadness
# message: ['buckeye state ya windows worry']
# category: fear
# message: ['So your notes about importClass and importPackage are no longer valid Except JavaScript is not discovered the right way when launching with Java 8 imputable to a glitch in the ImageJ Launcher']
# category: sadness
# message: ['Thanks hinerm']
# category: love
# message: ['Hopefully now that the unzip egress comprise fixed we will view less people hitting the timeout on window']
# category: joy

# %% [markdown]
# **Converting Augmented Data Back into Strings for Feature Extraction**

# %%
X_train = [' '.join(x) for x in X_train]

# %% [markdown]
# **Feature Extraction using TF-IDF**

# %%
vectorizer = TfidfVectorizer()
                         
X_train = vectorizer.fit_transform(X_train)
X_test = vectorizer.transform(X_test)

# %% [markdown]
# **Training the Dataset using Decision Tree Classifier**

# %%
#training the dataset using Decision Tree
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# **Testing and Evaluating the Model**

# %%
#predicting on the testing set
y_pred = model.predict(X_test)

#Generating Classification Report of the Model for Computing Precision, Recall and F1-Score for Every Six Emotion Categories
clsf_rprt = classification_report(y_test, y_pred)
print("Classification_report:\n", clsf_rprt)
# Out:
# Classification_report:
#                precision    recall  f1-score   support
#
#        anger       0.19      0.14      0.16        28
#         fear       0.39      0.41      0.40        78
#          joy       0.51      0.45      0.48        88
#         love       0.33      0.33      0.33         9
#      sadness       0.40      0.45      0.42        88
#     surprise       0.00      0.00      0.00         9
#
#     accuracy                           0.40       300
#    macro avg       0.30      0.30      0.30       300
# weighted avg       0.39      0.40      0.39       300

# %%
#calculating precision score
precision = precision_score(y_test, y_pred, average='weighted')
print("Precision (weighted):", precision)

#calculating recall score
recall = recall_score(y_test, y_pred, average='weighted')
print("Recall (weighted):", recall)

#calculating f1_score score
f1_score = f1_score(y_test, y_pred, average='weighted')
print("f1-score (weighted):", f1_score)

#calculating accuracy score
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Precision (weighted): 0.3927135655459705
# Recall (weighted): 0.39666666666666667
# f1-score (weighted): 0.3932733520766151
# Accuracy: 0.39666666666666667

# %% [markdown]
# **Testing the Efficiency of the Model with New Textual Messages Containing Emotion**

# %%
#predicting on new text data containing emotion
text_with_emotion = ["Unfortunately I am still stuck at the error"]
text_with_emotion = vectorizer.transform(text_with_emotion)
predicted_labels = model.predict(text_with_emotion)
print(predicted_labels)
# Out:
# ['sadness']
